# %%
import pandas as pd
import numpy as np

# read data
manipal_rains = pd.read_csv('../data/Task0/ManipalRains.csv')

# %%
# save data
manipal_rains.to_csv('../data/Task0/ManipalRains_PPD.csv', index=False)

# %% [markdown]
# # Sanity Check

# %%
# view metadata and summary
manipal_rains.info()
manipal_rains.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 68 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   MinTemp                    145460 non-null  float64
#  1   MaxTemp                    145460 non-null  float64
#  2   Rainfall                   145460 non-null  float64
#  3   WindGustDir                145460 non-null  int8
#  4   WindGustSpeed              145460 non-null  float64
#  5   WindDir9am                 145460 non-null  int8
#  6   WindDir3pm                 145460 non-null  int8
#  7   WindSpeed9am               145460 non-null  float64
#  8   WindSpeed3pm               145460 non-null  float64
#  9   Humidity9am                145460 non-null  float64
#  10  Humidity3pm                145460 non-null  float64
#  11  Pressure9am                145460 non-null  float64
#  12  Pressure3pm                145460 non-null  float64
#  13  Temp9am                    145460 non-null  float64
#  14  Temp3pm                    145460 non-null  float64
#  15  RainToday                  145460 non-null  int8
#  16  RainTomorrow               145460 non-null  int8
#  17  Location_Albany            145460 non-null  int64
#  18  Location_Albury            145460 non-null  int64
#  19  Location_AliceSprings      145460 non-null  int64
#  20  Location_BadgerysCreek     145460 non-null  int64
#  21  Location_Ballarat          145460 non-null  int64
#  22  Location_Bendigo           145460 non-null  int64
#  23  Location_Brisbane          145460 non-null  int64
#  24  Location_Cairns            145460 non-null  int64
#  25  Location_Canberra          145460 non-null  int64
#  26  Location_Cobar             145460 non-null  int64
#  27  Location_CoffsHarbour      145460 non-null  int64
#  28  Location_Dartmoor          145460 non-null  int64
#  29  Location_Darwin            145460 non-null  int64
#  30  Location_GoldCoast         145460 non-null  int64
#  31  Location_Hobart            145460 non-null  int64
#  32  Location_Katherine         145460 non-null  int64
#  33  Location_Launceston        145460 non-null  int64
#  34  Location_Melbourne         145460 non-null  int64
#  35  Location_MelbourneAirport  145460 non-null  int64
#  36  Location_Mildura           145460 non-null  int64
#  37  Location_Moree             145460 non-null  int64
#  38  Location_MountGambier      145460 non-null  int64
#  39  Location_MountGinini       145460 non-null  int64
#  40  Location_Newcastle         145460 non-null  int64
#  41  Location_Nhil              145460 non-null  int64
#  42  Location_NorahHead         145460 non-null  int64
#  43  Location_NorfolkIsland     145460 non-null  int64
#  44  Location_Nuriootpa         145460 non-null  int64
#  45  Location_PearceRAAF        145460 non-null  int64
#  46  Location_Penrith           145460 non-null  int64
#  47  Location_Perth             145460 non-null  int64
#  48  Location_PerthAirport      145460 non-null  int64
#  49  Location_Portland          145460 non-null  int64
#  50  Location_Richmond          145460 non-null  int64
#  51  Location_Sale              145460 non-null  int64
#  52  Location_SalmonGums        145460 non-null  int64
#  53  Location_Sydney            145460 non-null  int64
#  54  Location_SydneyAirport     145460 non-null  int64
#  55  Location_Townsville        145460 non-null  int64
#  56  Location_Tuggeranong       145460 non-null  int64
#  57  Location_Uluru             145460 non-null  int64
#  58  Location_WaggaWagga        145460 non-null  int64
#  59  Location_Walpole           145460 non-null  int64
#  60  Location_Watsonia          145460 non-null  int64
#  61  Location_Williamtown       145460 non-null  int64
#  62  Location_Witchcliffe       145460 non-null  int64
#  63  Location_Wollongong        145460 non-null  int64
#  64  Location_Woomera           145460 non-null  int64
#  65  Year                       145460 non-null  int32
#  66  Month                      145460 non-null  int32
#  67  Day                        145460 non-null  int32
# dtypes: float64(12), int32(3), int64(48), int8(5)
# memory usage: 68.9 MB
#              MinTemp        MaxTemp       Rainfall    WindGustDir  \
# count  145460.000000  145460.000000  145460.000000  145460.000000
# mean       12.192336      23.219758       0.381674       8.150179
# std         6.364499       7.067804       0.608638       4.959138
# min        -5.950000       2.700000       0.000000       0.000000
# 25%         7.700000      18.000000       0.000000       4.000000
# 50%        12.000000      22.600000       0.000000       9.000000
# 75%        16.800000      28.200000       0.600000      12.000000
# max        30.450000      43.500000       1.500000      16.000000
#
#        WindGustSpeed     WindDir9am    WindDir3pm   WindSpeed9am  \
# count   145460.00000  145460.000000  145460.00000  145460.000000
# mean        39.64328       7.749285       8.39261      13.939757
# std         12.17591       4.825041       4.91900       8.555976
# min          8.50000       0.000000       0.00000       0.000000
# 25%         31.00000       3.000000       4.00000       7.000000
# 50%         39.00000       8.000000       9.00000      13.000000
# 75%         46.00000      12.000000      13.00000      19.000000
# max         68.50000      16.000000      16.00000      37.000000
#
#         WindSpeed3pm    Humidity9am  ...  Location_WaggaWagga  \
# count  145460.000000  145460.000000  ...        145460.000000
# mean       18.583126      68.953025  ...             0.020686
# std         8.442404      18.704151  ...             0.142332
# min         0.000000      18.000000  ...             0.000000
# 25%        13.000000      57.000000  ...             0.000000
# 50%        19.000000      70.000000  ...             0.000000
# 75%        24.000000      83.000000  ...             0.000000
# max        40.500000     100.000000  ...             1.000000
#
#        Location_Walpole  Location_Watsonia  Location_Williamtown  \
# count     145460.000000      145460.000000         145460.000000
# mean           0.020665           0.020686              0.020686
# std            0.142262           0.142332              0.142332
# min            0.000000           0.000000              0.000000
# 25%            0.000000           0.000000              0.000000
# 50%            0.000000           0.000000              0.000000
# 75%            0.000000           0.000000              0.000000
# max            1.000000           1.000000              1.000000
#
#        Location_Witchcliffe  Location_Wollongong  Location_Woomera  \
# count         145460.000000        145460.000000     145460.000000
# mean               0.020686             0.020899          0.020686
# std                0.142332             0.143047          0.142332
# min                0.000000             0.000000          0.000000
# 25%                0.000000             0.000000          0.000000
# 50%                0.000000             0.000000          0.000000
# 75%                0.000000             0.000000          0.000000
# max                1.000000             1.000000          1.000000
#
#                 Year          Month            Day
# count  145460.000000  145460.000000  145460.000000
# mean     2012.769751       6.399615      15.712258
# std         2.537684       3.427262       8.794789
# min      2007.000000       1.000000       1.000000
# 25%      2011.000000       3.000000       8.000000
# 50%      2013.000000       6.000000      16.000000
# 75%      2015.000000       9.000000      23.000000
# max      2017.000000      12.000000      31.000000
#
# [8 rows x 68 columns]

# %%
# view the data
manipal_rains
# Out:
#         MinTemp  MaxTemp  Rainfall  WindGustDir  WindGustSpeed  WindDir9am  \
# 0          13.4     22.9  0.243240           14      10.532978          14
# 1           7.4     25.1  0.000000           15      10.532978           7
# 2          12.9     25.7  0.000000           16      10.801436          14
# 3           9.2     28.0  0.000000            5       7.383131          10
# 4          17.5     32.3  0.278771           14      10.117922           1
# ...         ...      ...       ...          ...            ...         ...
# 145455      2.8     23.4  0.000000            0       8.604092          10
# 145456      3.6     25.3  0.000000            7       7.000539          10
# 145457      5.4     26.9  0.000000            3       9.538737          10
# 145458      7.8     27.0  0.000000           10       8.100777          11
# 145459     14.9     22.6  0.000000            4       9.832249           2
#
#         WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  ...  \
# 0               15      9.056466     11.478667         71.0  ...
# 1               16      2.764694     10.771231         44.0  ...
# 2               16      8.738109     12.167810         38.0  ...
# 3                0      5.924970      5.511899         45.0  ...
# 4                8      4.247590     10.043357         82.0  ...
# ...            ...           ...           ...          ...  ...
# 145455           1      6.681995      6.425388         51.0  ...
# 145456           3      6.681995      5.511899         56.0  ...
# 145457          15      5.118305      5.511899         53.0  ...
# 145458           3      6.681995      4.536158         51.0  ...
# 145459           2      8.082667      8.907295         62.0  ...
#
#         Location_WaggaWagga  Location_Walpole  Location_Watsonia  \
# 0                         0                 0                  0
# 1                         0                 0                  0
# 2                         0                 0                  0
# 3                         0                 0                  0
# 4                         0                 0                  0
# ...                     ...               ...                ...
# 145455                    0                 0                  0
# 145456                    0                 0                  0
# 145457                    0                 0                  0
# 145458                    0                 0                  0
# 145459                    0                 0                  0
#
#         Location_Williamtown  Location_Witchcliffe  Location_Wollongong  \
# 0                          0                     0                    0
# 1                          0                     0                    0
# 2                          0                     0                    0
# 3                          0                     0                    0
# 4                          0                     0                    0
# ...                      ...                   ...                  ...
# 145455                     0                     0                    0
# 145456                     0                     0                    0
# 145457                     0                     0                    0
# 145458                     0                     0                    0
# 145459                     0                     0                    0
#
#         Location_Woomera  Year  Month  Day
# 0                      0  2008     12    1
# 1                      0  2008     12    2
# 2                      0  2008     12    3
# 3                      0  2008     12    4
# 4                      0  2008     12    5
# ...                  ...   ...    ...  ...
# 145455                 0  2017      6   21
# 145456                 0  2017      6   22
# 145457                 0  2017      6   23
# 145458                 0  2017      6   24
# 145459                 0  2017      6   25
#
# [145460 rows x 68 columns]

# %%
# check for duplicates
manipal_rains.duplicated().sum()

# check for null count
manipal_rains.isna().sum()

# check for %age of null values
manipal_rains.isna().sum() / manipal_rains.index.size * 100
# Out:
# Date              0.000000
# Location          0.000000
# MinTemp           1.020899
# MaxTemp           0.866905
# Rainfall          2.241853
# Evaporation      43.166506
# Sunshine         48.009762
# WindGustDir       7.098859
# WindGustSpeed     7.055548
# WindDir9am        7.263853
# WindDir3pm        2.906641
# WindSpeed9am      1.214767
# WindSpeed3pm      2.105046
# Humidity9am       1.824557
# Humidity3pm       3.098446
# Pressure9am      10.356799
# Pressure3pm      10.331363
# Cloud9am         38.421559
# Cloud3pm         40.807095
# Temp9am           1.214767
# Temp3pm           2.481094
# RainToday         2.241853
# RainTomorrow      2.245978
# dtype: float64

# %%
# check for consistency in the string features
manipal_rains.Location.value_counts()
manipal_rains.RainToday.value_counts()
manipal_rains.RainTomorrow.value_counts()
manipal_rains.WindGustDir.value_counts()
manipal_rains.WindDir3pm.value_counts()
# Out:
# WindDir3pm
# SE     10838
# W      10110
# S       9926
# WSW     9518
# SSE     9399
# SW      9354
# N       8890
# WNW     8874
# NW      8610
# ESE     8505
# E       8472
# NE      8263
# SSW     8156
# NNW     7870
# ENE     7857
# NNE     6590
# Name: count, dtype: int64

# %% [markdown]
# # Exploratory Data Analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Boxplot to detect outliers

fig, ax = plt.subplots(1, 2, figsize=(13, 4))
sns.boxplot(x=manipal_rains.MinTemp, ax=ax[0])
sns.boxplot(x=manipal_rains.MaxTemp, ax=ax[1])
plt.show()
fig, ax = plt.subplots(1, 3, figsize=(20, 4))
sns.boxplot(x=manipal_rains.Rainfall, ax=ax[0])
# sns.boxplot(x=manipal_rains.Evaporation, ax=ax[1])
# sns.boxplot(x=manipal_rains.Sunshine, ax=ax[2])
plt.show()
fig, ax = plt.subplots(1, 3, figsize=(20, 4))
sns.boxplot(x=manipal_rains.WindGustSpeed, ax=ax[0])
sns.boxplot(x=manipal_rains.WindSpeed9am, ax=ax[1])
sns.boxplot(x=manipal_rains.WindSpeed3pm, ax=ax[2])
plt.show()
# for i in ['Humidity', 'Pressure', 'Cloud', 'Temp']:
for i in ['Humidity', 'Pressure', 'Temp']:
    fig, ax = plt.subplots(1, 2, figsize=(13, 4))
    sns.boxplot(x=manipal_rains[i+'9am'], ax=ax[0])
    sns.boxplot(x=manipal_rains[i+'3pm'], ax=ax[1])
    plt.show()

# %% [markdown]
# # Missing Value Treatment

# %%
# since these features have a lot of null values, I choose to drop them
manipal_rains.drop(columns=['Evaporation', 'Sunshine', 'Cloud9am', 'Cloud3pm'], inplace=True)

# %%
# from sklearn.impute import KNNImputer
#
# # I try KNN-imputing the rest
# imputer = KNNImputer()
# imputer.fit_transform(manipal_rains.select_dtypes('number'))

# %%
# KNN-imputing takes an unrealistically long amount of time, so I use median
for i in manipal_rains.select_dtypes('number').columns:
    manipal_rains[i] = manipal_rains[i].fillna(manipal_rains[i].median())

# %%
# Since RainToday and RainTomorrow are binary, I choose to fill with the mode of the feature, which is 'No'
manipal_rains.RainToday = manipal_rains.RainToday.fillna(manipal_rains.RainToday.mode()[0])
manipal_rains.RainTomorrow = manipal_rains.RainTomorrow.fillna(manipal_rains.RainTomorrow.mode()[0])

# I choose to fill wind directions with a third value
manipal_rains.loc[:, ['WindGustDir', 'WindDir9am', 'WindDir3pm']]\
    = manipal_rains.loc[:, ['WindGustDir', 'WindDir9am', 'WindDir3pm']].fillna('NA')

# %% [markdown]
# # Outlier Treatment & Misc

# %%
# Interquartile-based clipping of numerical columns
for i in manipal_rains.select_dtypes('number').columns:
    q1, q3 = manipal_rains[i].quantile([.25, .75])
    iqr = q3 - q1
    manipal_rains[i] = manipal_rains[i].clip(q1 - iqr*1.5, q3 + iqr*1.5)

# %%
# since Date has no null values, I attempt to parse it
manipal_rains.Date = pd.to_datetime(manipal_rains.Date, format='%d-%m-%Y')

# %% [markdown]
# # Numeric Encoding

# %%
# Label encoding
manipal_rains.RainToday = manipal_rains.RainToday.astype('category').cat.codes
manipal_rains.RainTomorrow = manipal_rains.RainToday.astype('category').cat.codes
manipal_rains.WindGustDir = manipal_rains.WindGustDir.astype('category').cat.codes
manipal_rains.WindDir9am = manipal_rains.WindDir9am.astype('category').cat.codes
manipal_rains.WindDir3pm = manipal_rains.WindDir3pm.astype('category').cat.codes

# %%
# One Hot encoding
dummy = pd.get_dummies(manipal_rains, columns=['Location'], dtype=int, drop_first=True)
manipal_rains = dummy

# %%
# Date encoding
manipal_rains['Year'] = manipal_rains.Date.dt.year
manipal_rains['Month'] = manipal_rains.Date.dt.month
manipal_rains['Day'] = manipal_rains.Date.dt.day
manipal_rains.drop(columns=['Date'], inplace=True)

# %% [markdown]
# # Scaling & Normalization
#
# > Application of either of these depends on the algorithm being used

# %%
from mlxtend.preprocessing import minmax_scaling

# Scaling

# print(*[i for i in list(manipal_rains.columns) if not i.startswith('Location')])
scale_columns = ['MinTemp', 'MaxTemp', 'Rainfall', 'WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Temp9am', 'Temp3pm']
manipal_rains[scale_columns] = minmax_scaling(manipal_rains[scale_columns], columns=scale_columns)

# %%
from scipy.stats import boxcox

# Normalization

norm_columns = ['Rainfall', 'WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm']
# Idk if there's any need to normalize the humidity features

# some columns may have 0 values, so I'm adding a small constant
for i in norm_columns:
    if np.any(manipal_rains[i] == 0):
        manipal_rains[i] += 1

for i in norm_columns:
    manipal_rains[i] = boxcox(manipal_rains[i])[0]
